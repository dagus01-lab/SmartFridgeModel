# %% [markdown]
# # Synthetic dataset generation

# %%
# !python3 synthetic_data.py -f synthetic_dataset.yaml
# Out:
# ...
# Processing test dataset files: 100%|████████| 273/273 [00:38<00:00,  7.18file/s]

# %% [markdown]
# # Some examples of generated images

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
supported_formats = ('.png', '.jpg', '.jpeg', '.gif', '.bmp')
images_dir = 'dataset/synthetic_dataset/train/images'
image_files = [f for f in os.listdir(images_dir) if f.lower().endswith(supported_formats)]

for image_file in image_files[:10]:
    image_path = os.path.join(images_dir, image_file)
    image = Image.open(image_path)
        
    plt.figure()
    plt.imshow(image)
    plt.axis('off')
    plt.show()
